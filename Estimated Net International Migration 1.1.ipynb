# %% [markdown]
# Table 1.1: Estimated Net International Migration (year ending mid-2001 to year ending mid-2017)

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.nisra.gov.uk/sites/nisra.gov.uk/files/publications/Mig1617-Official.xlsx'
inputFile = sourceFolder / 'Mig1617-Official.xlsx'
response = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='Table 1.1')[0]
# Out:
# Loading in\Mig1617-Official.xlsx which has size 194382 bytes
# Table names: ['Table 1.1']

# %%
tab
# Out:
# {<B17 13300.0>, <A14 'Jul 2010 - Jun 2011'>, <B11 18261.0>, <A19 'Jul 2015 - Jun 2016'>, <B13 13877.0>, <B20 11310.0>, <B15 12922.0>, <A20 'Jul 2016 - Jun 2017'>, <B9 15803.0>, <C16 13623.0>, <D11 6280.0>, <D12 2998.0>, <A6 'Jul 2002 - Jun 2003'>, <D21 37116.0>, <C6 6683.0>, <D10 9140.0>, <A18 'Jul 2014 - Jun 2015'>, <E18 'Jul 14 - Jun 15'>, <C19 11540.0>, <E19 'Jul 15 - Jun 16'>, <A8 'Jul 2004 - Jun 2005'>, <E4 'Jul 00 - Jun 01'>, <C7 6996.0>, <C9 8797.0>, <D18 2795.0>, <A5 'Jul 2001 - Jun 2002'>, <D3 'Net International Migration'>, <E7 'Jul 03 - Jun 04'>, <D8 3683.0>, <B2 ''>, <B8 12544.0>, <E14 'Jul 10 - Jun 11'>, <D16 -887.0>, <B7 8174.0>, <C17 11063.0>, <A11 'Jul 2007 - Jun 2008'>, <A2 ''>, <E17 'Jul 13 - Jun 14'>, <B21 212418.0>, <E2 ''>, <A4 'Jul 2000 - Jun 2001'>, <C20 10727.0>, <D15 442.0>, <D4 -1085.0>, <A21 'Total'>, <A17 'Jul 2013 - Jun 2014'>, <B3 'International Inflows'>, <E15 'Jul 11 - Jun 12'>, <D6 127.0>, <C15 12480.0>, <C1 ''>, <C13 12115.0>, <E9 'Jul 05 - Jun 06'>, <A3 'Time-period'>, <E5 'Jul 01 - Jun 02'>, <C18 10298.0>, <E20 'Jul 16 - Jun 17'>, <E6 'Jul 02 - Jun 03'>, <E13 'Jul 09 - Jun 10'>, <A7 'Jul 2003 - Jun 2004'>, <A1 'Table 1.1: Estimated Net International Migration (year ending mid-2001 to year ending mid-2017)'>, <C10 10633.0>, <C12 11406.0>, <A10 'Jul 2006 - Jun 2007'>, <B6 6810.0>, <C14 14097.0>, <B10 19773.0>, <B16 12736.0>, <D9 7006.0>, <B12 14404.0>, <C3 'International Outflows'>, <C21 175302.0>, <D5 95.0>, <E21 ''>, <C2 ''>, <A12 'Jul 2008 - Jun 2009'>, <E8 'Jul 04 - Jun 05'>, <C8 8861.0>, <B1 ''>, <B18 13093.0>, <E12 'Jul 08 - Jun 09'>, <D17 2237.0>, <B14 13401.0>, <C4 7609.0>, <D19 1458.0>, <A15 'Jul 2011 - Jun 2012'>, <E3 ''>, <E1 ''>, <E11 'Jul 07 - Jun 08'>, <B5 6488.0>, <D14 -696.0>, <A16 'Jul 2012 - Jun 2013'>, <A13 'Jul 2009 - Jun 2010'>, <D2 ''>, <E16 'Jul 12 - Jun 13'>, <C5 6393.0>, <D1 ''>, <E10 'Jul 06 - Jun 07'>, <B4 6524.0>, <A9 'Jul 2005 - Jun 2006'>, <D13 1762.0>, <D20 583.0>, <C11 11981.0>, <D7 1178.0>, <B19 12998.0>}

# %%
# tab = pd.read_excel(inputFile, header = None, sheet_name = 1)
# tab

# %%
observations = tab.excel_ref('B4').expand(DOWN).expand(RIGHT).is_not_blank()- tab.excel_ref('E4').expand(DOWN).expand(RIGHT)

# %%
observations
# Out:
# {<C18 10298.0>, <B17 13300.0>, <D8 3683.0>, <B8 12544.0>, <B18 13093.0>, <B11 18261.0>, <C17 11063.0>, <D16 -887.0>, <B7 8174.0>, <B13 13877.0>, <B20 11310.0>, <B15 12922.0>, <D17 2237.0>, <D19 1458.0>, <C4 7609.0>, <B14 13401.0>, <B21 212418.0>, <C16 13623.0>, <B9 15803.0>, <D11 6280.0>, <C20 10727.0>, <B5 6488.0>, <C10 10633.0>, <C12 11406.0>, <D15 442.0>, <D14 -696.0>, <D4 -1085.0>, <D12 2998.0>, <B6 6810.0>, <D21 37116.0>, <C6 6683.0>, <D10 9140.0>, <C14 14097.0>, <C19 11540.0>, <B10 19773.0>, <D6 127.0>, <B16 12736.0>, <D9 7006.0>, <C5 6393.0>, <B12 14404.0>, <C15 12480.0>, <C13 12115.0>, <B4 6524.0>, <D13 1762.0>, <D20 583.0>, <C7 6996.0>, <C21 175302.0>, <D5 95.0>, <C9 8797.0>, <D18 2795.0>, <C11 11981.0>, <C8 8861.0>, <D7 1178.0>, <B19 12998.0>}

# %%
Flow = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
Flow
# Out:
# {<B3 'International Inflows'>, <D3 'Net International Migration'>, <C3 'International Outflows'>}

# %%
MidYear = tab.excel_ref('A4').expand(DOWN) - tab.excel_ref('A22').expand(DOWN)  
MidYear
# Out:
# {<A21 'Total'>, <A6 'Jul 2002 - Jun 2003'>, <A14 'Jul 2010 - Jun 2011'>, <A17 'Jul 2013 - Jun 2014'>, <A18 'Jul 2014 - Jun 2015'>, <A8 'Jul 2004 - Jun 2005'>, <A19 'Jul 2015 - Jun 2016'>, <A11 'Jul 2007 - Jun 2008'>, <A7 'Jul 2003 - Jun 2004'>, <A20 'Jul 2016 - Jun 2017'>, <A15 'Jul 2011 - Jun 2012'>, <A9 'Jul 2005 - Jun 2006'>, <A4 'Jul 2000 - Jun 2001'>, <A16 'Jul 2012 - Jun 2013'>, <A13 'Jul 2009 - Jun 2010'>, <A12 'Jul 2008 - Jun 2009'>, <A10 'Jul 2006 - Jun 2007'>, <A5 'Jul 2001 - Jun 2002'>}

# %%
Dimensions = [
            HDim(MidYear,'Mid Year',DIRECTLY,LEFT),
            HDim(Flow,'Flow',DIRECTLY, ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#          OBS             Mid Year                         Flow Measure Type  \
# 0     6524.0  Jul 2000 - Jun 2001        International Inflows        Count
# 1     7609.0  Jul 2000 - Jun 2001       International Outflows        Count
# 2    -1085.0  Jul 2000 - Jun 2001  Net International Migration        Count
# 3     6488.0  Jul 2001 - Jun 2002        International Inflows        Count
# 4     6393.0  Jul 2001 - Jun 2002       International Outflows        Count
# 5       95.0  Jul 2001 - Jun 2002  Net International Migration        Count
# 6     6810.0  Jul 2002 - Jun 2003        International Inflows        Count
# 7     6683.0  Jul 2002 - Jun 2003       International Outflows        Count
# 8      127.0  Jul 2002 - Jun 2003  Net International Migration        Count
# 9     8174.0  Jul 2003 - Jun 2004        International Inflows        Count
# 10    6996.0  Jul 2003 - Jun 2004       International Outflows        Count
# 11    1178.0  Jul 2003 - Jun 2004  Net International Migration        Count
# 12   12544.0  Jul 2004 - Jun 2005        International Inflows        Count
# 13    8861.0  Jul 2004 - Jun 2005       International Outflows        Count
# 14    3683.0  Jul 2004 - Jun 2005  Net International Migration        Count
# 15   15803.0  Jul 2005 - Jun 2006        International Inflows        Count
# 16    8797.0  Jul 2005 - Jun 2006       International Outflows        Count
# 17    7006.0  Jul 2005 - Jun 2006  Net International Migration        Count
# 18   19773.0  Jul 2006 - Jun 2007        International Inflows        Count
# 19   10633.0  Jul 2006 - Jun 2007       International Outflows        Count
# 20    9140.0  Jul 2006 - Jun 2007  Net International Migration        Count
# 21   18261.0  Jul 2007 - Jun 2008        International Inflows        Count
# 22   11981.0  Jul 2007 - Jun 2008       International Outflows        Count
# 23    6280.0  Jul 2007 - Jun 2008  Net International Migration        Count
# 24   14404.0  Jul 2008 - Jun 2009        International Inflows        Count
# 25   11406.0  Jul 2008 - Jun 2009       International Outflows        Count
# 26    2998.0  Jul 2008 - Jun 2009  Net International Migration        Count
# 27   13877.0  Jul 2009 - Jun 2010        International Inflows        Count
# 28   12115.0  Jul 2009 - Jun 2010       International Outflows        Count
# 29    1762.0  Jul 2009 - Jun 2010  Net International Migration        Count
# 30   13401.0  Jul 2010 - Jun 2011        International Inflows        Count
# 31   14097.0  Jul 2010 - Jun 2011       International Outflows        Count
# 32    -696.0  Jul 2010 - Jun 2011  Net International Migration        Count
# 33   12922.0  Jul 2011 - Jun 2012        International Inflows        Count
# 34   12480.0  Jul 2011 - Jun 2012       International Outflows        Count
# 35     442.0  Jul 2011 - Jun 2012  Net International Migration        Count
# 36   12736.0  Jul 2012 - Jun 2013        International Inflows        Count
# 37   13623.0  Jul 2012 - Jun 2013       International Outflows        Count
# 38    -887.0  Jul 2012 - Jun 2013  Net International Migration        Count
# 39   13300.0  Jul 2013 - Jun 2014        International Inflows        Count
# 40   11063.0  Jul 2013 - Jun 2014       International Outflows        Count
# 41    2237.0  Jul 2013 - Jun 2014  Net International Migration        Count
# 42   13093.0  Jul 2014 - Jun 2015        International Inflows        Count
# 43   10298.0  Jul 2014 - Jun 2015       International Outflows        Count
# 44    2795.0  Jul 2014 - Jun 2015  Net International Migration        Count
# 45   12998.0  Jul 2015 - Jun 2016        International Inflows        Count
# 46   11540.0  Jul 2015 - Jun 2016       International Outflows        Count
# 47    1458.0  Jul 2015 - Jun 2016  Net International Migration        Count
# 48   11310.0  Jul 2016 - Jun 2017        International Inflows        Count
# 49   10727.0  Jul 2016 - Jun 2017       International Outflows        Count
# 50     583.0  Jul 2016 - Jun 2017  Net International Migration        Count
# 51  212418.0                Total        International Inflows        Count
# 52  175302.0                Total       International Outflows        Count
# 53   37116.0                Total  Net International Migration        Count
#
#       Unit
# 0   People
# 1   People
# 2   People
# 3   People
# 4   People
# 5   People
# 6   People
# 7   People
# 8   People
# 9   People
# 10  People
# 11  People
# 12  People
# 13  People
# 14  People
# 15  People
# 16  People
# 17  People
# 18  People
# 19  People
# 20  People
# 21  People
# 22  People
# 23  People
# 24  People
# 25  People
# 26  People
# 27  People
# 28  People
# 29  People
# 30  People
# 31  People
# 32  People
# 33  People
# 34  People
# 35  People
# 36  People
# 37  People
# 38  People
# 39  People
# 40  People
# 41  People
# 42  People
# 43  People
# 44  People
# 45  People
# 46  People
# 47  People
# 48  People
# 49  People
# 50  People
# 51  People
# 52  People
# 53  People

# %%
new_table['OBS'] = new_table['OBS'].astype(int)

# %%
new_table.dtypes
# Out:
# OBS              int32
# Mid Year        object
# Flow            object
# Measure Type    object
# Unit            object
# dtype: object

# %%
new_table['Mid Year'] = new_table['Mid Year'].map(lambda cell:cell.replace('Total', 'all years'))

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table['Flow'] = new_table['Flow'].map(
    lambda x: {
        'Net International Migration' : 'Balance', 
        'International Inflows' : 'Inflow',
        'International Outflows': 'Outflow'         
        }.get(x, x))

# %%
new_table = new_table[['Mid Year','Flow','Measure Type','Value','Unit']]

# %%
new_table.head(5)
# Out:
#               Mid Year     Flow Measure Type  Value    Unit
# 0  Jul 2000 - Jun 2001   Inflow        Count   6524  People
# 1  Jul 2000 - Jun 2001  Outflow        Count   7609  People
# 2  Jul 2000 - Jun 2001  Balance        Count  -1085  People
# 3  Jul 2001 - Jun 2002   Inflow        Count   6488  People
# 4  Jul 2001 - Jun 2002  Outflow        Count   6393  People

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('tidydata1.1.csv'), index = False)
