# %% [markdown]
# Table 1.2: Estimated Net International Migration, by Local Government District (year ending mid-2007 to year ending mid-2017)

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.nisra.gov.uk/sites/nisra.gov.uk/files/publications/Mig1617-Official.xlsx'
inputFile = sourceFolder / 'Mig1617-Official.xlsx'
response = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='Table 1.2')[0]
# Out:
# Loading in\Mig1617-Official.xlsx which has size 194382 bytes
# Table names: ['Table 1.2']

# %%
tab
# Out:
# {<L5 -106.0>, <M41 108.0>, <D14 495.0>, <E39 41.0>, <K5 -74.0>, <K19 ''>, <H6 555.0>, <N44 ''>, <N14 'Mid Ulster'>, <F27 -1247.0>, <E36 216.0>, <M39 437.0>, <C43 -84.0>, <F5 -226.0>, <G45 -105.0>, <C44 -56.0>, <D12 293.0>, <A31 'Cookstown'>, <H18 ''>, <C1 ''>, <E6 665.0>, <N6 'Causeway Coast & Glens'>, <C13 1336.0>, <H23 141.0>, <A9 'Derry City & Strabane'>, <J27 568.0>, <O43 ''>, <F11 -56.0>, <I19 ''>, <M4 'Total'>, <J6 1086.0>, <O25 ''>, <M8 -832.0>, <J32 863.0>, <N39 ''>, <F43 -252.0>, <L16 583.0>, <F29 -84.0>, <O35 ''>, <O9 527.0>, <O17 ''>, <N31 ''>, <I30 -92.0>, <F4 '                     Jul 2010 - Jun 2011'>, <G39 -45.0>, <F8 -67.0>, <K7 -580.0>, <A7 'Belfast'>, <J14 428.0>, <N4 'LGD'>, <D41 -3.0>, <G27 -502.0>, <I11 13.0>, <E18 ''>, <H31 -26.0>, <L37 15.0>, <L26 71.0>, <I3 ''>, <J8 -68.0>, <J25 41.0>, <N5 'Derry City & Strabane'>, <J44 -105.0>, <H8 -136.0>, <N23 ''>, <B41 17.0>, <E23 285.0>, <C23 261.0>, <O16 ''>, <E26 0.0>, <K16 1458.0>, <G24 129.0>, <B13 2195.0>, <L14 491.0>, <E31 67.0>, <D15 27.0>, <J28 3.0>, <F33 -388.0>, <B27 1656.0>, <A34 'Down'>, <C17 ''>, <E2 ''>, <K37 34.0>, <H47 -887.0>, <J5 13.0>, <D34 53.0>, <F24 150.0>, <M15 -65.0>, <E37 5.0>, <F22 24.0>, <G10 -68.0>, <F37 7.0>, <D29 39.0>, <I16 2237.0>, <G5 -80.0>, <A16 'Northern Ireland'>, <L8 -168.0>, <D2 ''>, <D7 765.0>, <M11 561.0>, <I39 -1.0>, <E34 12.0>, <L23 189.0>, <E20 '                     Jul 2009 - Jun 2010'>, <N47 ''>, <K33 -103.0>, <E44 9.0>, <C40 213.0>, <D37 30.0>, <M36 1205.0>, <A29 'Castlereagh'>, <B37 23.0>, <K21 45.0>, <L9 -187.0>, <N46 ''>, <J45 121.0>, <E30 -128.0>, <O10 561.0>, <K1 ''>, <G8 -71.0>, <E40 106.0>, <O30 ''>, <M21 828.0>, <N38 ''>, <A22 'Ards'>, <M42 5139.0>, <F17 ''>, <A5 'Antrim & Newtownabbey'>, <C21 314.0>, <C31 246.0>, <F32 425.0>, <C22 65.0>, <G16 442.0>, <E4 '                     Jul 2009 - Jun 2010'>, <H2 ''>, <O40 ''>, <J34 79.0>, <O22 ''>, <N30 ''>, <F28 -69.0>, <B31 384.0>, <E13 656.0>, <L35 191.0>, <H10 -13.0>, <F35 405.0>, <K43 -119.0>, <L40 24.0>, <K24 494.0>, <A35 'Dungannon'>, <N22 ''>, <D28 -15.0>, <G30 -144.0>, <H41 11.0>, <M18 ''>, <N15 'Armagh City, Banbridge & Craigavon'>, <B21 391.0>, <J37 16.0>, <E29 -36.0>, <C15 10.0>, <F1 ''>, <D18 ''>, <O1 ''>, <M5 -740.0>, <F20 '                     Jul 2010 - Jun 2011'>, <C26 88.0>, <A42 'Newry and Mourne'>, <F26 -15.0>, <F16 -696.0>, <G32 447.0>, <H11 -51.0>, <L18 ''>, <A39 'Lisburn'>, <M16 26112.0>, <H9 -336.0>, <D21 54.0>, <C45 338.0>, <M46 -160.0>, <L38 -8.0>, <B4 '                     Jul 2006 - Jun 2007'>, <A26 'Banbridge'>, <K17 ''>, <M2 ''>, <B9 60.0>, <M10 2648.0>, <D24 278.0>, <F10 135.0>, <J40 10.0>, <O6 -832.0>, <H22 -15.0>, <D6 749.0>, <A18 ''>, <J10 47.0>, <B47 9140.0>, <I42 360.0>, <L2 ''>, <K22 54.0>, <D33 -77.0>, <L34 131.0>, <O41 ''>, <G43 -105.0>, <D47 2998.0>, <B42 1278.0>, <K23 198.0>, <G40 16.0>, <H28 -24.0>, <N33 ''>, <J21 106.0>, <L22 68.0>, <G26 -3.0>, <K39 -227.0>, <E21 28.0>, <K38 6.0>, <G31 57.0>, <M43 -1568.0>, <A1 'Table 1.2: Estimated Net International Migration, by Local Government District (year ending mid-2007 to year ending mid-2017)'>, <E11 27.0>, <K11 -233.0>, <O33 ''>, <J46 -18.0>, <O31 ''>, <M9 -2238.0>, <N25 ''>, <E43 -361.0>, <A2 ''>, <I36 37.0>, <M7 527.0>, <K10 124.0>, <F9 -462.0>, <C30 96.0>, <G14 170.0>, <O23 ''>, <M38 -28.0>, <O8 -65.0>, <N17 ''>, <I40 128.0>, <J22 12.0>, <B36 387.0>, <D30 -139.0>, <G21 25.0>, <E28 0.0>, <L45 84.0>, <G15 36.0>, <B20 '                     Jul 2006 - Jun 2007'>, <H24 161.0>, <F12 88.0>, <E25 7.0>, <D25 29.0>, <K27 -573.0>, <G33 -281.0>, <G42 219.0>, <I27 363.0>, <O5 -2238.0>, <B38 41.0>, <F30 -98.0>, <F23 200.0>, <I5 -126.0>, <G47 442.0>, <G12 107.0>, <E8 -195.0>, <M13 8156.0>, <N1 ''>, <I4 '                     Jul 2013 - Jun 2014'>, <A6 'Armagh City, Banbridge & Craigavon'>, <C46 66.0>, <J15 -92.0>, <B17 ''>, <H20 '                     Jul 2012 - Jun 2013'>, <G9 -311.0>, <K32 687.0>, <D43 -30.0>, <K47 1458.0>, <N41 ''>, <K35 404.0>, <G28 -27.0>, <H19 ''>, <G41 28.0>, <H7 -1064.0>,  ...

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank()- tab.excel_ref('N5').expand(DOWN).expand(RIGHT)

# %%
observations = observations - tab.excel_ref('B20').expand(RIGHT)

# %%
Area = tab.excel_ref('A5').expand(DOWN).is_not_blank()
Area
# Out:
# {<A26 'Banbridge'>, <A10 'Fermanagh & Omagh'>, <A25 'Ballymoney'>, <A11 'Lisburn & Castlereagh'>, <A13 'Mid Ulster'>, <A31 'Cookstown'>, <A35 'Dungannon'>, <A29 'Castlereagh'>, <A9 'Derry City & Strabane'>, <A28 'Carrickfergus'>, <A32 'Craigavon'>, <A37 'Larne'>, <A43 'Newtownabbey'>, <A21 'Antrim'>, <A23 'Armagh'>, <A14 'Newry, Mourne & Down'>, <A15 'Ards & North Down'>, <A44 'North Down'>, <A46 'Strabane'>, <A34 'Down'>, <A36 'Fermanagh'>, <A42 'Newry and Mourne'>, <A8 'Causeway Coast & Glens'>, <A20 'Area (Former LGD)'>, <A38 'Limavady'>, <A47 'Northern Ireland'>, <A33 'Derry'>, <A39 'Lisburn'>, <A22 'Ards'>, <A45 'Omagh'>, <A24 'Ballymena'>, <A27 'Belfast'>, <A5 'Antrim & Newtownabbey'>, <A41 'Moyle'>, <A12 'Mid & East Antrim'>, <A6 'Armagh City, Banbridge & Craigavon'>, <A40 'Magherafelt'>, <A16 'Northern Ireland'>, <A30 'Coleraine'>, <A7 'Belfast'>}

# %%
MidYear = tab.excel_ref('B4').expand(RIGHT) - tab.excel_ref('N4').expand(RIGHT)  
MidYear
# Out:
# {<L4 '                     Jul 2016 - Jun 2017'>, <M4 'Total'>, <K4 '                     Jul 2015 - Jun 2016'>, <D4 '                     Jul 2008 - Jun 2009'>, <E4 '                     Jul 2009 - Jun 2010'>, <H4 '                     Jul 2012 - Jun 2013'>, <I4 '                     Jul 2013 - Jun 2014'>, <F4 '                     Jul 2010 - Jun 2011'>, <G4 '                     Jul 2011 - Jun 2012'>, <J4 '                     Jul 2014 - Jun 2015'>, <C4 '                     Jul 2007 - Jun 2008'>, <B4 '                     Jul 2006 - Jun 2007'>}

# %%
Dimensions = [
            HDim(MidYear,'Mid Year',DIRECTLY,ABOVE),
            HDim(Area,'Area',DIRECTLY, LEFT),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#          OBS                                  Mid Year  \
# 0      259.0                       Jul 2006 - Jun 2007
# 1      230.0                       Jul 2007 - Jun 2008
# 2       24.0                       Jul 2008 - Jun 2009
# 3     -333.0                       Jul 2009 - Jun 2010
# 4     -226.0                       Jul 2010 - Jun 2011
# 5      -80.0                       Jul 2011 - Jun 2012
# 6     -321.0                       Jul 2012 - Jun 2013
# 7     -126.0                       Jul 2013 - Jun 2014
# 8       13.0                       Jul 2014 - Jun 2015
# 9      -74.0                       Jul 2015 - Jun 2016
# 10    -106.0                       Jul 2016 - Jun 2017
# 11    -740.0                                     Total
# 12    1363.0                       Jul 2006 - Jun 2007
# 13    1212.0                       Jul 2007 - Jun 2008
# 14     749.0                       Jul 2008 - Jun 2009
# 15     665.0                       Jul 2009 - Jun 2010
# 16     615.0                       Jul 2010 - Jun 2011
# 17     690.0                       Jul 2011 - Jun 2012
# 18     555.0                       Jul 2012 - Jun 2013
# 19     870.0                       Jul 2013 - Jun 2014
# 20    1086.0                       Jul 2014 - Jun 2015
# 21     949.0                       Jul 2015 - Jun 2016
# 22     705.0                       Jul 2016 - Jun 2017
# 23    9459.0                                     Total
# 24    1661.0                       Jul 2006 - Jun 2007
# 25     798.0                       Jul 2007 - Jun 2008
# 26     765.0                       Jul 2008 - Jun 2009
# 27     349.0                       Jul 2009 - Jun 2010
# 28   -1346.0                       Jul 2010 - Jun 2011
# 29    -499.0                       Jul 2011 - Jun 2012
# ..       ...                                       ...
# 438    -59.0                       Jul 2012 - Jun 2013
# 439    159.0                       Jul 2013 - Jun 2014
# 440    121.0                       Jul 2014 - Jun 2015
# 441     43.0                       Jul 2015 - Jun 2016
# 442     84.0                       Jul 2016 - Jun 2017
# 443   1443.0                                     Total
# 444      8.0                       Jul 2006 - Jun 2007
# 445     66.0                       Jul 2007 - Jun 2008
# 446    -94.0                       Jul 2008 - Jun 2009
# 447    -53.0                       Jul 2009 - Jun 2010
# 448    -74.0                       Jul 2010 - Jun 2011
# 449    -30.0                       Jul 2011 - Jun 2012
# 450    -28.0                       Jul 2012 - Jun 2013
# 451     -7.0                       Jul 2013 - Jun 2014
# 452    -18.0                       Jul 2014 - Jun 2015
# 453     28.0                       Jul 2015 - Jun 2016
# 454     42.0                       Jul 2016 - Jun 2017
# 455   -160.0                                     Total
# 456   9140.0                       Jul 2006 - Jun 2007
# 457   6280.0                       Jul 2007 - Jun 2008
# 458   2998.0                       Jul 2008 - Jun 2009
# 459   1762.0                       Jul 2009 - Jun 2010
# 460   -696.0                       Jul 2010 - Jun 2011
# 461    442.0                       Jul 2011 - Jun 2012
# 462   -887.0                       Jul 2012 - Jun 2013
# 463   2237.0                       Jul 2013 - Jun 2014
# 464   2795.0                       Jul 2014 - Jun 2015
# 465   1458.0                       Jul 2015 - Jun 2016
# 466    583.0                       Jul 2016 - Jun 2017
# 467  26112.0                                     Total
#
#                                    Area Measure Type    Unit
# 0                 Antrim & Newtownabbey        Count  People
# 1                 Antrim & Newtownabbey        Count  People
# 2                 Antrim & Newtownabbey        Count  People
# 3                 Antrim & Newtownabbey        Count  People
# 4                 Antrim & Newtownabbey        Count  People
# 5                 Antrim & Newtownabbey        Count  People
# 6                 Antrim & Newtownabbey        Count  People
# 7                 Antrim & Newtownabbey        Count  People
# 8                 Antrim & Newtownabbey        Count  People
# 9                 Antrim & Newtownabbey        Count  People
# 10                Antrim & Newtownabbey        Count  People
# 11                Antrim & Newtownabbey        Count  People
# 12   Armagh City, Banbridge & Craigavon        Count  People
# 13   Armagh City, Banbridge & Craigavon        Count  People
# 14   Armagh City, Banbridge & Craigavon        Count  People
# 15   Armagh City, Banbridge & Craigavon        Count  People
# 16   Armagh City, Banbridge & Craigavon        Count  People
# 17   Armagh City, Banbridge & Craigavon        Count  People
# 18   Armagh City, Banbridge & Craigavon        Count  People
# 19   Armagh City, Banbridge & Craigavon        Count  People
# 20   Armagh City, Banbridge & Craigavon        Count  People
# 21   Armagh City, Banbridge & Craigavon        Count  People
# 22   Armagh City, Banbridge & Craigavon        Count  People
# 23   Armagh City, Banbridge & Craigavon        Count  People
# 24                              Belfast        Count  People
# 25                              Belfast        Count  People
# 26                              Belfast        Count  People
# 27                              Belfast        Count  People
# 28                              Belfast        Count  People
# 29                              Belfast        Count  People
# ..                                  ...          ...     ...
# 438                               Omagh        Count  People
# 439                               Omagh        Count  People
# 440                               Omagh        Count  People
# 441                               Omagh        Count  People
# 442                               Omagh        Count  People
# 443                               Omagh        Count  People
# 444                            Strabane        Count  People
# 445                            Strabane        Count  People
# 446                            Strabane        Count  People
# 447                            Strabane        Count  People
# 448                            Strabane        Count  People
# 449                            Strabane        Count  People
# 450                            Strabane        Count  People
# 451                            Strabane        Count  People
# 452                            Strabane        Count  People
# 453                            Strabane        Count  People
# 454                            Strabane        Count  People
# 455                            Strabane        Count  People
# 456                    Northern Ireland        Count  People
# 457                    Northern Ireland        Count  People
# 458                    Northern Ireland        Count  People
# 459                    Northern Ireland        Count  People
# 460                    Northern Ireland        Count  People
# 461                    Northern Ireland        Count  People
# 462                    Northern Ireland        Count  People
# 463                    Northern Ireland        Count  People
# 464                    Northern Ireland        Count  People
# 465                    Northern Ireland        Count  People
# 466                    Northern Ireland        Count  People
# 467                    Northern Ireland        Count  People
#
# [468 rows x 5 columns]

# %%
new_table['OBS'] = new_table['OBS'].astype(int)

# %%
new_table.dtypes
# Out:
# OBS              int32
# Mid Year        object
# Area            object
# Measure Type    object
# Unit            object
# dtype: object

# %%
def remove_whitespace(x):
    
    try:
        x = "".join(x.split())

    except:
        pass
    return x

new_table['Mid Year'] = new_table['Mid Year'].apply(remove_whitespace)

# %%
new_table['Mid Year'] = new_table['Mid Year'].map(lambda cell:cell.replace('Total', 'all years'))

# %%
# new_table['Mid Year'].str.ljust

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table = new_table[['Mid Year','Area','Measure Type','Value','Unit']]

# %%
new_table.head(5)
# Out:
#           Mid Year                   Area Measure Type  Value    Unit
# 0  Jul2006-Jun2007  Antrim & Newtownabbey        Count    259  People
# 1  Jul2007-Jun2008  Antrim & Newtownabbey        Count    230  People
# 2  Jul2008-Jun2009  Antrim & Newtownabbey        Count     24  People
# 3  Jul2009-Jun2010  Antrim & Newtownabbey        Count   -333  People
# 4  Jul2010-Jun2011  Antrim & Newtownabbey        Count   -226  People

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('tidydata1.2.csv'), index = False)
